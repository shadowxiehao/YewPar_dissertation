# %% [markdown]
# evaluation for maxclique solo

# %%
import matplotlib.pyplot as plt
import numpy as np

# Localities
localities = [20, 15, 10, 5]

# Performance-Driven Workstealing Policy times
pdw_times = [
    [14829, 12791, 16863, 17266, 16410, 13920, 14489, 17646, 21343, 12549],
    [21533, 19751, 20677, 25336, 21294, 25132, 18389, 17850, 19703, 16009],
    [24463, 27543, 25995, 32465, 32764, 25782, 27933, 22756, 32031, 23569],
    [51414, 64284, 58569, 66468, 65849, 55616, 62883, 64843, 63617, 60311]
]

# Depth Pool Workstealing Policy times
dpw_times = [
    [16893, 15822, 17997, 15739, 16006, 13570, 17827, 17189, 16246, 12595],
    [21678, 22525, 19146, 18976, 20766, 22809, 19951, 20347, 21012, 19747],
    [29963, 28186, 28006, 32229, 27420, 29927, 29617, 28761, 28925, 26073],
    [79945, 50156, 51396, 53098, 99086, 99490, 75471, 51503, 64685, 68091]
]

# Calculate the average times for each policy
avg_pdw_times = [np.mean(times) for times in pdw_times]
avg_dpw_times = [np.mean(times) for times in dpw_times]

# Calculate speedup percentages
speedup_percentages = [(dpw - pdw) / dpw * 100 for dpw, pdw in zip(avg_dpw_times, avg_pdw_times)]

# Adjusting the titles, colors, and the y-axis scaling for the average time graph

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 10))

# Plotting the time difference for each locality with a logarithmic scale
ax1.plot(localities, avg_pdw_times, marker='o', label='Performance-Driven', color='dodgerblue')
ax1.plot(localities, avg_dpw_times, marker='o', label='Depth Pool', color='coral')
ax1.set_yscale('log')
ax1.set_xlabel('Localities')
ax1.set_ylabel('Average Time (ms, log scale)')
ax1.set_title('Average Time Comparison for Maxclique-16')
ax1.legend()
ax1.grid(True, which="both", ls="--", c='0.65')

# Plotting the speedup percentages
bars = ax2.bar(localities, speedup_percentages, color=['limegreen' if percent > 0 else 'tomato' for percent in speedup_percentages])
ax2.plot(localities, speedup_percentages, marker='o', color='lightseagreen', label='Percentage Change')
ax2.set_xlabel('Localities')
ax2.set_ylabel('Speedup Percentage (%)')
ax2.set_title('Speedup Percentage using Performance-Driven for Maxclique-16')
ax2.legend()
ax2.grid(True, axis='y', ls="--", c='0.65')

# Annotating the bars with their respective percentages
for bar in bars:
    yval = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom', color='black')

plt.tight_layout()
plt.savefig("../images/time_comparison_max_solo.pdf")
plt.show()

# %% [markdown]
# evaluation for NS-hivert solo

# %%
import matplotlib.pyplot as plt
import numpy as np

# Localities
localities = [20, 15, 10, 5]

# Performance-Driven Workstealing Policy times
pdw_times = [
    [8942,9064,8978,8932,8904,8932,8966,9013,8956,8962],
    [11710,11826,11760,11772,11750,11760,11975,11757,11801,11746],
    [17445,17532,17515,17455,17486,17432,17525,17484,17506,17464],
    [34922,34849,34898,34913,34891,34926,34960,34891,34919,34859]
]

# Depth Pool Workstealing Policy times
dpw_times = [
    [9882,9948,9954,9978,9945,9989,9871,10042,10016,10056],
    [13005,13007,13054,13031,13051,13061,13039,12982,13024,13096],
    [19111,19149,19033,19113,19222,19072,19072,19023,19256,19037],
    [37633,37703,37710,37650,37613,37668,37720,37571,37682,37563]
]

# Calculate the average times for each policy
avg_pdw_times = [np.mean(times) for times in pdw_times]
avg_dpw_times = [np.mean(times) for times in dpw_times]

# Calculate speedup percentages
speedup_percentages = [(dpw - pdw) / dpw * 100 for dpw, pdw in zip(avg_dpw_times, avg_pdw_times)]

# Adjusting the titles, colors, and the y-axis scaling for the average time graph

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 10))

# Plotting the time difference for each locality with a logarithmic scale
ax1.plot(localities, avg_pdw_times, marker='o', label='Performance-Driven', color='dodgerblue')
ax1.plot(localities, avg_dpw_times, marker='o', label='Depth Pool', color='coral')
ax1.set_yscale('log')
ax1.set_xlabel('Localities')
ax1.set_ylabel('Average Time (ms, log scale)')
ax1.set_title('Average Time Comparison for NS-hivert')
ax1.legend()
ax1.grid(True, which="both", ls="--", c='0.65')

# Plotting the speedup percentages
bars = ax2.bar(localities, speedup_percentages, color=['limegreen' if percent > 0 else 'tomato' for percent in speedup_percentages])
ax2.plot(localities, speedup_percentages, marker='o', color='lightseagreen', label='Percentage Change')
ax2.set_xlabel('Localities')
ax2.set_ylabel('Speedup Percentage (%)')
ax2.set_title('Speedup Percentage using Performance-Driven for NS-hivert')
ax2.legend()
ax2.grid(True, axis='y', ls="--", c='0.65')

# Annotating the bars with their respective percentages
for bar in bars:
    yval = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom', color='black')

plt.tight_layout()
plt.savefig("../images/time_comparison_ns_solo.pdf")
plt.show()

# %%
# evaluation for maxclique run simultaneously
#

import matplotlib.pyplot as plt
import numpy as np

# Localities
localities = [20, 15, 10, 5]

# Performance-Driven Workstealing Policy times
pdw_times = [
    [29660,40314,37144,33314,37146,35187,39280,38449,30695,31253],
    [49062,45182,50122,40388,38596,53504,61126,34767,52585,43253],
    [66531,66494,60935,50364,56088,58545,60509,55681,63372,69744],
    [104810,106080,114325,127025,125424,119856,129894,121873,129900,128109]
]

# Depth Pool Workstealing Policy times
dpw_times = [
    [34990,37954,42202,35970,39627,37308,47165,34588,36364,36959],
    [54296,57342,45869,52949,50054,51638,67120,37218,42635,43020],
    [62531,91967,80865,55159,56090,60476,77641,82621,61687,69789],
    [102019,158790,103343,130167,164195,114820,132898,108817,116030,135588]
]

# Calculate the average times for each policy
avg_pdw_times = [np.mean(times) for times in pdw_times]
avg_dpw_times = [np.mean(times) for times in dpw_times]

# Calculate speedup percentages
speedup_percentages = [(dpw - pdw) / dpw * 100 for dpw, pdw in zip(avg_dpw_times, avg_pdw_times)]

# Adjusting the titles, colors, and the y-axis scaling for the average time graph

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 10))

# Plotting the time difference for each locality with a logarithmic scale
ax1.plot(localities, avg_pdw_times, marker='o', label='Performance-Driven', color='dodgerblue')
ax1.plot(localities, avg_dpw_times, marker='o', label='Depth Pool', color='coral')
ax1.set_yscale('log')
ax1.set_xlabel('Localities')
ax1.set_ylabel('Average Time (ms, log scale)')
ax1.set_title('Average Time Comparison for Maxclique-16')
ax1.legend()
ax1.grid(True, which="both", ls="--", c='0.65')

# Plotting the speedup percentages
bars = ax2.bar(localities, speedup_percentages, color=['limegreen' if percent > 0 else 'tomato' for percent in speedup_percentages])
ax2.plot(localities, speedup_percentages, marker='o', color='lightseagreen', label='Percentage Change')
ax2.set_xlabel('Localities')
ax2.set_ylabel('Speedup Percentage (%)')
ax2.set_title('Speedup Percentage using Performance-Driven for Maxclique-16')
ax2.legend()
ax2.grid(True, axis='y', ls="--", c='0.65')

# Annotating the bars with their respective percentages
for bar in bars:
    yval = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom', color='black')

plt.tight_layout()
plt.savefig("../images/time_comparison_max_simultaneously.pdf")
plt.show()

# %%
# evaluation for maxclique run simultaneously
#

import matplotlib.pyplot as plt
import numpy as np

# Localities
localities = [20, 15, 10, 5]

# Performance-Driven Workstealing Policy times
pdw_times = [
    [22083,22416,22299,20514,20333,22946,23012,21001,20655,23120],
    [26867,27067,28235,27508,25723,25471,28208,28128,26254,28272],
    [39736,37963,38072,40323,38470,39852,37845,40796,38552,39475],
    [75818,76999,76251,77031,75488,76587,76455,75528,75964,74382]
]

# Depth Pool Workstealing Policy times
dpw_times = [
    [25004,25496,25477,25484,24855,25586,25632,24856,24180,25778],
    [32329,31555,31457,30250,30670,30431,31528,31524,31236,32640],
    [44152,42980,44011,43471,43557,43119,44620,43576,45429,43059],
    [84444,82186,83962,84170,85396,81858,81957,85656,84645,84748]
]

# Calculate the average times for each policy
avg_pdw_times = [np.mean(times) for times in pdw_times]
avg_dpw_times = [np.mean(times) for times in dpw_times]

# Calculate speedup percentages
speedup_percentages = [(dpw - pdw) / dpw * 100 for dpw, pdw in zip(avg_dpw_times, avg_pdw_times)]

# Adjusting the titles, colors, and the y-axis scaling for the average time graph

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 10))

# Plotting the time difference for each locality with a logarithmic scale
ax1.plot(localities, avg_pdw_times, marker='o', label='Performance-Driven', color='dodgerblue')
ax1.plot(localities, avg_dpw_times, marker='o', label='Depth Pool', color='coral')
ax1.set_yscale('log')
ax1.set_xlabel('Localities')
ax1.set_ylabel('Average Time (ms, log scale)')
ax1.set_title('Average Time Comparison for NS-hivert')
ax1.legend()
ax1.grid(True, which="both", ls="--", c='0.65')

# Plotting the speedup percentages
bars = ax2.bar(localities, speedup_percentages, color=['limegreen' if percent > 0 else 'tomato' for percent in speedup_percentages])
ax2.plot(localities, speedup_percentages, marker='o', color='lightseagreen', label='Percentage Change')
ax2.set_xlabel('Localities')
ax2.set_ylabel('Speedup Percentage (%)')
ax2.set_title('Speedup Percentage using Performance-Driven for NS-hivert')
ax2.legend()
ax2.grid(True, axis='y', ls="--", c='0.65')

# Annotating the bars with their respective percentages
for bar in bars:
    yval = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom', color='black')

plt.tight_layout()
plt.savefig("../images/time_comparison_ns_simultaneously.pdf")
plt.show()

# %%
#image to show maxclique fluctuations

import matplotlib.pyplot as plt
import numpy as np

# Given data
performance_driven_data = [24463,27543,25995,32465,32764,25782,27933,22756,32031,23569]
depthpool_data = [29963,28186,28006,32229,27420,29927,29617,28761,28925,26073]
x = np.arange(len(performance_driven_data))

# Plotting the data again
fig, ax = plt.subplots(2, 1, figsize=(10, 8), sharex=True)

ax[0].plot(x, performance_driven_data, 'o-', label="Performance-Driven Workstealing", color='blue')
ax[0].set_title("Performance-Driven Workstealing Policy")
ax[0].set_ylabel("Run Time (ms)")
ax[0].grid(True, which="both", ls="--", c='0.7')
ax[0].legend()

ax[1].plot(x, depthpool_data, 'o-', label="DepthPool Workstealing", color='green')
ax[1].set_title("DepthPool Workstealing Policy")
ax[1].set_xlabel("Run Iteration")
ax[1].set_ylabel("Run Time (ms)")
ax[1].grid(True, which="both", ls="--", c='0.7')
ax[1].legend()

plt.tight_layout()
plt.savefig("../images/maxclique_16_fluctuations.pdf")
plt.show()

# %%
# Data for Performance-Driven Workstealing Policy and DepthPool Workstealing Policy
performance_driven_data = [24463, 27543, 25995, 32465, 32764, 25782, 27933, 22756, 32031, 23569]
depthpool_data = [29963, 28186, 28006, 32229, 27420, 29927, 29617, 28761, 28925, 26073]

# Calculate the percentage difference for each data set
def calculate_percentage_difference(data):
    return ((max(data) - min(data)) / min(data)) * 100

performance_driven_difference = calculate_percentage_difference(performance_driven_data)
depthpool_difference = calculate_percentage_difference(depthpool_data)

performance_driven_difference, depthpool_difference
# Out:
# (43.979609773246615, 23.610631687953052)

# %%
#image to show NS-hivert fluctuations

import matplotlib.pyplot as plt
import numpy as np

# Given data
performance_driven_data = [17445,17532,17515,17455,17486,17432,17525,17484,17506,17464]
depthpool_data = [19111,19149,19033,19113,19222,19072,19072,19023,19256,19037]
x = np.arange(len(performance_driven_data))

# Plotting the data again
fig, ax = plt.subplots(2, 1, figsize=(10, 8), sharex=True)

ax[0].plot(x, performance_driven_data, 'o-', label="Performance-Driven Workstealing", color='blue')
ax[0].set_title("Performance-Driven Workstealing Policy")
ax[0].set_ylabel("Run Time (ms)")
ax[0].grid(True, which="both", ls="--", c='0.7')
ax[0].legend()

ax[1].plot(x, depthpool_data, 'o-', label="DepthPool Workstealing", color='green')
ax[1].set_title("DepthPool Workstealing Policy")
ax[1].set_xlabel("Run Iteration")
ax[1].set_ylabel("Run Time (ms)")
ax[1].grid(True, which="both", ls="--", c='0.7')
ax[1].legend()

plt.tight_layout()
plt.savefig("../images/NS_hivert_fluctuations.pdf")
plt.show()

# %%
# Data for Performance-Driven Workstealing Policy and DepthPool Workstealing Policy
performance_driven_data = [17445,17532,17515,17455,17486,17432,17525,17484,17506,17464]
depthpool_data = [19111,19149,19033,19113,19222,19072,19072,19023,19256,19037]

# Calculate the percentage difference for each data set
def calculate_percentage_difference(data):
    return ((max(data) - min(data)) / min(data)) * 100

performance_driven_difference = calculate_percentage_difference(performance_driven_data)
depthpool_difference = calculate_percentage_difference(depthpool_data)

performance_driven_difference, depthpool_difference
# Out:
# (0.5736576411197797, 1.2248330967775851)

# %%
# evaluation for ns run with one thread
#

import matplotlib.pyplot as plt
import numpy as np

# Localities

# Performance-Driven Workstealing Policy times
pdw_times = [16386,16382,16384,16380,16374,16395,16383,16381,16363,16382]

# Depth Pool Workstealing Policy times
dpw_times = [16715,16776,16738,16709,16753,16750,16755,16750,16740,16735]

x = np.arange(len(pdw_times))

# Calculate the average times for each policy
avg_pdw_times = [np.mean(times) for times in pdw_times]
avg_dpw_times = [np.mean(times) for times in dpw_times]

# Calculate speedup percentages
speedup_percentages = [(dpw - pdw) / dpw * 100 for dpw, pdw in zip(avg_dpw_times, avg_pdw_times)]

# Adjusting the titles, colors, and the y-axis scaling for the average time graph

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 10))

# Plotting the time difference for each locality with a logarithmic scale
ax1.plot(x, avg_pdw_times, marker='o', label='Performance-Driven', color='dodgerblue')
ax1.plot(x, avg_dpw_times, marker='o', label='Depth Pool', color='coral')
ax1.set_yscale('log')
ax1.set_xlabel('Run Iteration')
ax1.set_ylabel('Average Time (ms, log scale)')
ax1.set_title('Average Time Comparison for NS-hivert')
ax1.legend()
ax1.grid(True, which="both", ls="--", c='0.65')

# Plotting the speedup percentages
bars = ax2.bar(x, speedup_percentages, color=['limegreen' if percent > 0 else 'tomato' for percent in speedup_percentages])
ax2.plot(x, speedup_percentages, marker='o', color='lightseagreen', label='Percentage Change')
ax2.set_xlabel('Run Iteration')
ax2.set_ylabel('Speedup Percentage (%)')
ax2.set_title('Speedup Percentage using Performance-Driven for NS-hivert')
ax2.legend()
ax2.grid(True, axis='y', ls="--", c='0.65')

# Annotating the bars with their respective percentages
for bar in bars:
    yval = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom', color='black')

plt.tight_layout()
plt.savefig("../images/time_comparison_ns_one_worker.pdf")
plt.show()
